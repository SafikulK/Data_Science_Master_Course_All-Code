# %%
d = { }

# %%
type(d)
# Out:
# dict

# %%
d1=  { "name" : "safikul" , "phone" : 707654 , "gmil" : "@gmail.com"}

# %%
d1
# Out:
# {'name': 'safikul', 'phone': 707654, 'gmil': '@gmail.com'}

# %%
type(d1)
# Out:
# dict

# %%
d1["gmil"]
# Out:
# '@gmail.com'

# %%
d1[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 d1[1]
#
# KeyError: 1

# %%
d2 ={ "name" :"safi" ,"tahe" : "you"  , "name" : "tahe "}

# %%
d2[ "name"]
# Out:
# 'tahe '

# %%
d3 = {"com" : "pwsk" ,"cou" : ["web" , "data S" , "java"] }

# %%
d3
# Out:
# {'com': 'pwsk', 'cou': ['web', 'data S', 'java']}

# %%
d3["com"]
# Out:
# 'pwsk'

# %%
d3["cou"][1]
# Out:
# 'data S'

# %%
d5 = {"num" : [1,2,8,7,45] , "Assig" : (1,2,5,48,5) , " L date " : { 15,9,2026}, "class time ":{ "data "  : 8, "java": 10}  }

# %%
d5
# Out:
# {'num': [1, 2, 8, 7, 45],
#  'Assig': (1, 2, 5, 48, 5),
#  ' L date ': {9, 15, 2026},
#  'class time ': {'data ': 8, 'java': 10}}

# %%
d5 [ "class time "]["java"]
# Out:
# 10

# %%
d5 ["mentor" ] = [ "saif" , "tahe " ]

# %%
d5
# Out:
# {'num': [1, 2, 8, 7, 45],
#  'Assig': (1, 2, 5, 48, 5),
#  ' L date ': {9, 15, 2026},
#  'class time ': {'data ': 8, 'java': 10},
#  'mentor': ['saif', 'tahe ']}

# %%
d5.keys()
# Out:
# dict_keys(['num', 'Assig', ' L date ', 'class time ', 'mentor'])

# %%
d5.values()
# Out:
# dict_values([[1, 2, 8, 7, 45], (1, 2, 5, 48, 5), {9, 2026, 15}, {'data ': 8, 'java': 10}, ['saif', 'tahe ']])

# %%
list (d5.items())
# Out:
# [('num', [1, 2, 8, 7, 45]),
#  ('Assig', (1, 2, 5, 48, 5)),
#  (' L date ', {9, 15, 2026}),
#  ('class time ', {'data ': 8, 'java': 10}),
#  ('mentor', ['saif', 'tahe '])]

# %%
d5.pop("num")
# Out:
# [1, 2, 8, 7, 45]

# %%
d5
# Out:
# {'Assig': (1, 2, 5, 48, 5),
#  ' L date ': {9, 15, 2026},
#  'class time ': {'data ': 8, 'java': 10},
#  'mentor': ['saif', 'tahe ']}

# %%
marks = 80
if marks >= 80:
    print("you part A")
elif marks >=60:
    print("you part of B")
elif marks >=40:
    print("you part of C")
else:
    print("U on D")
# Out:
# you part A

# %%
marks = int (input( "you number" ))
if marks >=80:
    print("you on A batch")
elif marks >=60 and marks <80:
    print("yo on b batch")
elif marks >=40 and marks <60:
    print("you on c batch")
else :
    print("d")
# Out:
# you on A batch

# %%
price = int(input ("youtr nmber "))
if price > 1000:
    print("not take ")
else :
    print(" take ")
# Out:
#  take

# %%
price = int(input ("youtr nmber "))
if price > 1000:
    print("not take ")
    if price >5000:
        print("tooo much")
    elif price <2000 :
        print("ok")
# Out:
# not take

# %%
l = [ 1,2,3,4,5,6,7,8,9]

# %%
type(l)
# Out:
# list
