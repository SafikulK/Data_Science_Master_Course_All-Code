# %%
l = [ 1,2,3,4,5,6]
l1 = []
for i in l:
    l1.append(i**2)

# %%
l1
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
[ i**2 for i in  l]
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
l  = [ 1,2,4,5,78,8,4 ]
l1 = []
for i in l:
    l1.append(i**2)

# %%
l1
# Out:
# [1, 4, 16, 25, 6084, 64, 16]

# %%
l
# Out:
# [1, 2, 4, 5, 78, 8, 4]

# %%
[i ** 2 for i in l ]
# Out:
# [1, 4, 16, 25, 6084, 64, 16]

# %%
[ i for i in l if i % 2 ==0]
# Out:
# [2, 4, 78, 8, 4]

# %%
l1 =  ["saif " , "data" , "tahe" , "wow" ]

# %%
[i.upper() for i in l1]
# Out:
# ['SAIF ', 'DATA', 'TAHE', 'WOW']

# %%
l
# Out:
# [1, 2, 4, 5, 78, 8, 4]

# %%
list (i ** 2 for i in l)
# Out:
# [1, 4, 16, 25, 6084, 64, 16]

# %%
d={"name":8 , "what":528}

# %%
{name:what**2 for name , what in d.items()}
# Out:
# {'name': 64, 'what': 278784}
