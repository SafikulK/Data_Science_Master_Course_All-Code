# %%
#start my new code here it conncrt to dicaet to github

# %%
# list is a collection of items that can be of different data types.
# it could be anything like numbers, strings, or even other lists. lists are mutable, meaning you can change their contents after they are created. 
# they are defined using square brackets [] and items are separated by commas.

# %%
l = [ 1,85,45, 425.24 , 124.25 , "safikul" , "Arhan" , True , False , 52+85j ]

# %%
type(l)
# Out:
# list

# %%
l [3:5]
# Out:
# [425.24, 124.25]

# %%
l[9::]
# Out:
# [(52+85j)]

# %%
l [ 9]
# Out:
# (52+85j)

# %%
l [7:9]
# Out:
# [True, False]

# %%
l [ 5:7]
# Out:
# ['safikul', 'Arhan']

# %%
l [0:3 ]
# Out:
# [1, 85, 45]

# %%
l [ 0]
# Out:
# 1

# %%
l [ 3]
# Out:
# 425.24

# %%
l [ 6]
# Out:
# 'Arhan'

# %%
l [ 5:7]
# Out:
# ['safikul', 'Arhan']

# %%
l [ ]
# Out:
#   Cell In[52], line 1
#     l [ ]
#         ^
# SyntaxError: invalid syntax

# %%
l
# Out:
# [1, 85, 45, 425.24, 124.25, 'safikul', 'Arhan', True, False, (52+85j)]

# %%
l [ ::-1]
# Out:
# [(52+85j), False, True, 'Arhan', 'safikul', 124.25, 425.24, 45, 85, 1]

# %%
l [ ::2]
# Out:
# [1, 45, 124.25, 'Arhan', False]

# %%
s = "pwskill"

# %%
l[5][0:4]
# Out:
# 'safi'

# %%
l1 = [ 12,14,5]

# %%
l+l1
# Out:
# [1,
#  85,
#  45,
#  425.24,
#  124.25,
#  'safikul',
#  'Arhan',
#  True,
#  False,
#  (52+85j),
#  12,
#  14,
#  5]

# %%
l
# Out:
# [1, 85, 45, 425.24, 124.25, 'safikul', 'Arhan', True, False, (52+85j)]

# %%
l1*3
# Out:
# [12, 14, 5, 12, 14, 5, 12, 14, 5]

# %%
len(l)
# Out:
# 10

# %%
l.append(45)

# %%
l
# Out:
# [1, 85, 45, 425.24, 124.25, 'safikul', 'Arhan', True, False, (52+85j), 45]

# %%
l.append(s)

# %%
s
# Out:
# 'pwskill'

# %%
l
# Out:
# [1,
#  85,
#  45,
#  425.24,
#  124.25,
#  'safikul',
#  'Arhan',
#  True,
#  False,
#  (52+85j),
#  45,
#  'pwskill']

# %%
l
# Out:
# [1,
#  85,
#  45,
#  425.24,
#  124.25,
#  'safikul',
#  'Arhan',
#  True,
#  False,
#  (52+85j),
#  45,
#  'pwskill']

# %%
l.append(l1)

# %%
l
# Out:
# [1,
#  85,
#  45,
#  425.24,
#  124.25,
#  'safikul',
#  'Arhan',
#  True,
#  False,
#  (52+85j),
#  45,
#  'pwskill',
#  [12, 14, 5]]

# %%
l[12][1]
# Out:
# 14

# %%
l[-1][1]
# Out:
# 14

# %%
l
# Out:
# [1,
#  85,
#  45,
#  425.24,
#  124.25,
#  'safikul',
#  'Arhan',
#  True,
#  False,
#  (52+85j),
#  45,
#  'pwskill',
#  [12, 14, 5]]

# %%
l.extend("saif")

# %%
l
# Out:
# [1,
#  85,
#  45,
#  425.24,
#  124.25,
#  'safikul',
#  'Arhan',
#  True,
#  False,
#  (52+85j),
#  45,
#  'pwskill',
#  [12, 14, 5],
#  's',
#  'a',
#  'i',
#  'f']

# %%
l.extend([1,2,4,5])

# %%
l
# Out:
# [1,
#  85,
#  45,
#  425.24,
#  124.25,
#  'safikul',
#  'Arhan',
#  True,
#  False,
#  (52+85j),
#  45,
#  'pwskill',
#  [12, 14, 5],
#  's',
#  'a',
#  'i',
#  'f',
#  1,
#  2,
#  4,
#  5]

# %%
len(l)
# Out:
# 21

# %%
# different between append and extend is that append adds its argument as a single element to the end of a list,
# while extend iterates over its argument adding each element to the list, extending the list. 
# List Length: append() always increases the list length by 1. extend() increases the length by the total number of items inside the added iterable.

# %%
# in simple words, append() adds its argument as a single element to the end of a list,
# while extend() iterates over its argument adding each element to the list, extending the list.

# %%
l.insert(2, 10)

# %%
l.insert(-1,45)

# %%
l
# Out:
# [100,
#  1,
#  85,
#  10,
#  45,
#  425.24,
#  124.25,
#  'safikul',
#  'Arhan',
#  True,
#  False,
#  (52+85j),
#  45,
#  'pwskill',
#  [12, 14, 5],
#  's',
#  'a',
#  'i',
#  'f',
#  1,
#  2,
#  4,
#  45,
#  5]

# %%
l.insert(0,100)

# %%
l
# Out:
# [1,
#  85,
#  10,
#  45,
#  425.24,
#  124.25,
#  'safikul',
#  'Arhan',
#  True,
#  False,
#  (52+85j),
#  45,
#  'pwskill',
#  [12, 14, 5],
#  's',
#  'a',
#  'i',
#  'f',
#  1,
#  2,
#  4,
#  45,
#  5]

# %%
l
# Out:
# [1,
#  85,
#  10,
#  45,
#  425.24,
#  124.25,
#  'safikul',
#  'Arhan',
#  True,
#  False,
#  (52+85j),
#  45,
#  'pwskill',
#  [12, 14, 5],
#  's',
#  'a',
#  'i',
#  'f',
#  1,
#  2,
#  4,
#  5]

# %%
# in a list when you we input data that time we have 3 option to add data 
# when your data need end of your list you can used tow option append() and extend()  
# bt depend on data you used this two oprion if your data is single value then you can used append() and if your data is multiple value then you can used extend()
# now you can all you have to with end list and if you want to add data in middle of your list then you can used insert() function

# 1. append() - adds its argument as a single element to the end of a list
# 2. extend() - iterates over its argument adding each element to the list, extending the list
# 3. insert() - adds its argument at a specific index in the list

# %%
# append()
l2 = [ 12,14,5]

# %%
l2.append("safikul")

# %%
l2
# Out:
# [12, 14, 5, 'safikul']

# %%
l2.append(8547)

# %%
l2
# Out:
# [12, 14, 5, 'safikul', 8547]

# %%
#extend()
l2
# Out:
# [12, 14, 5, 'safikul', 8547]

# %%
l2.extend("safikul ")

# %%
l2
# Out:
# [12, 14, 5, 'safikul', 8547, 's', 's', 'a', 'f', 'i', 'k', 'u', 'l', ' ']

# %%
l2.extend(8577)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 l2.extend(8577)
#
# TypeError: 'int' object is not iterable

# %%
l2.extend("8577")

# %%
l2
# Out:
# [12,
#  14,
#  5,
#  'safikul',
#  8547,
#  's',
#  's',
#  'a',
#  'f',
#  'i',
#  'k',
#  'u',
#  'l',
#  ' ',
#  '8',
#  '5',
#  '7',
#  '7']

# %%
l2.insert(0, "done")

# %%
l2
# Out:
# ['done',
#  12,
#  14,
#  5,
#  'safikul',
#  8547,
#  's',
#  's',
#  'a',
#  'f',
#  'i',
#  'k',
#  'u',
#  'l',
#  ' ',
#  '8',
#  '5',
#  '7',
#  '7']

# %%
l2.insert(9,100)

# %%
l2
# Out:
# ['done',
#  12,
#  14,
#  5,
#  'safikul',
#  8547,
#  's',
#  's',
#  'a',
#  100,
#  'f',
#  'i',
#  'k',
#  'u',
#  'l',
#  ' ',
#  '8',
#  '5',
#  '7',
#  '7']

# %%
# insert and append are do the same work in terms of input data 
#but both work diffently, append() adds its argument as a single element to the end of a list,
# while insert() adds its argument at a specific index in the list.

# %%
l2
# Out:
# ['done',
#  12,
#  14,
#  5,
#  'safikul',
#  8547,
#  's',
#  's',
#  'a',
#  'f',
#  'i',
#  'k',
#  'u',
#  'l',
#  ' ',
#  '8',
#  '5',
#  '7',
#  '7']

# %%
l1
# Out:
# [12, 14, 5]

# %%
l2
# Out:
# ['done',
#  12,
#  14,
#  5,
#  'safikul',
#  8547,
#  's',
#  's',
#  'a',
#  100,
#  'f',
#  'i',
#  'k',
#  'u',
#  'l',
#  ' ',
#  '8',
#  '5',
#  '7',
#  '7']

# %%
l2.pop()
# Out:
# '7'

# %%
l2
# Out:
# ['done',
#  12,
#  14,
#  5,
#  'safikul',
#  8547,
#  's',
#  's',
#  'a',
#  100,
#  'f',
#  'i',
#  'k',
#  'u',
#  'l',
#  ' ',
#  '8',
#  '5',
#  '7']

# %%
l2.pop(7)
# Out:
# 's'

# %%
l2
# Out:
# ['done',
#  12,
#  14,
#  5,
#  'safikul',
#  8547,
#  's',
#  'a',
#  100,
#  'f',
#  'i',
#  'k',
#  'u',
#  'l',
#  ' ',
#  '8',
#  '5',
#  '7']

# %%
#pop() method removes last of list or you have option to seletc a index and you can remove that index value from list.

# %%
l2.remove("done")

# %%
l2
# Out:
# [12,
#  14,
#  5,
#  'safikul',
#  8547,
#  's',
#  'a',
#  100,
#  'f',
#  'i',
#  'k',
#  'u',
#  'l',
#  ' ',
#  '8',
#  '5',
#  '7']

# %%
l2.remove(12)

# %%
l2
# Out:
# [14,
#  5,
#  'safikul',
#  8547,
#  's',
#  'a',
#  100,
#  'f',
#  'i',
#  'k',
#  'u',
#  'l',
#  ' ',
#  '8',
#  '5',
#  '7']

# %%
#remove is used for remove a specific value from the list.

# %%
l4 = [ 12,14,5,5 ,[ 14 , 85 , ]]

# %%
l4.remove(14)

# %%
l4
# Out:
# [12, 14, 5, 5, [14, 85]]

# %%
l4[::-1]
# Out:
# [[14, 85], 5, 5, 12]

# %%
l4.reverse()

# %%
l4
# Out:
# [12, 14, 5, 5, [14, 85]]

# %%
l4
# Out:
# [12, 14, 5, 5, [14, 85]]

# %%
l4.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 l4.sort()
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
l5 =[ 100,85,17,1,2,4,9]

# %%
l5.sort()

# %%
l5
# Out:
# [1, 2, 4, 9, 17, 85, 100]

# %%
l6 = [ "safikul" , "data ", "bata" , "ai" , "zip"]

# %%
l6.sort()

# %%
l6
# Out:
# ['ai', 'bata', 'data ', 'safikul', 'zip']

# %%
s = "saif"

# %%
s [0] = "t"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 s [0] = "t"
#
# TypeError: 'str' object does not support item assignment

# %%
s1 = [ 1,8,7,8,8]

# %%
s1 [ 0] = 100

# %%
s1
# Out:
# [100, 8, 7, 8, 8]

# %%
s
# Out:
# 'saif'

# %%
s.replace(  "s" , "t")
# Out:
# 'taif'

# %%
t =( 12,42.25 , "SAFI" , True ,41+85j ,[4,8,] )

# %%
t
# Out:
# (12, 42.25, 'SAFI', True, (41+85j), [4, 8])

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 6

# %%
t[1]
# Out:
# 42.25

# %%
t[5]
# Out:
# [4, 8]

# %%
l4
# Out:
# [5, 5, 12, 14, [14, 85]]

# %%
l4[0] = 2025

# %%
l4
# Out:
# [2025, 5, 12, 14, [14, 85]]

# %%
l10 = ["saif" ,"tahe    "]

# %%
l10
# Out:
# ['saif', 'tahe    ']

# %%
l10[0] = 4178

# %%
l10
# Out:
# [4178, 'tahe    ']

# %%
t[0]="safi"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 t[0]="safi"
#
# TypeError: 'tuple' object does not support item assignment

# %%
# tuple and str both are in immutable

# %%
#Mutable objects act like open containers. You can add, remove, or modify their contents in place without changing the object's unique identity (its memory address)

# %%
#Immutable objects act like sealed boxes. Once created, their internal state cannot be altered. Any operation that appears to modify an immutable object actually creates a brand-new object in memory and updates the variable to point to it

# %%
t[::-1]
# Out:
# ([4, 8], (41+85j), True, 'SAFI', 42.25, 12)

# %%
t.count(12)
# Out:
# 1

# %%
t.index(True)
# Out:
# 3

# %%
s11 = {}

# %%
type(s11)
# Out:
# dict

# %%
s12= { 1,78,4,2,5}

# %%
type(s12)
# Out:
# set

# %%
s13 = {[4, 8], (41+85j), True, 'safi', 42.25, 12,(1,25,8)}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 s13 = {[4, 8], (41+85j), True, 'safi', 42.25, 12,(1,25,8)}
#
# TypeError: unhashable type: 'list'

# %%
s14 = { (41+85j), True, 'safi', 42.25, 12,(1,25,8)}

# %%
type(s14)
# Out:
# set

# %%
s15= { 22,45,45,22, 8 , 9, 8,9,11,11,20}

# %%
type(s15)
# Out:
# set
