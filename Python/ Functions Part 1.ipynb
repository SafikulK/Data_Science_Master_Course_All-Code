# %%
# Functions Part 1

# %%
print("this my  Functions Part ")
# Out:
# this my  Functions Part

# %%
l  = [ 324 , 45,45]

# %%
len(l)
# Out:
# 3

# %%
type(l)
# Out:
# list

# %%
def test():
    pass

# %%
def test():
    print("this my first  Functions Part 1")

# %%
test()
# Out:
# this my first  Functions Part 1

# %%
def test2():
    return "this is my very first return"

# %%
test2()
# Out:
# 'this is my very first return'

# %%
test2 () +  " saif"
# Out:
# 'this is my very first return saif'

# %%
def test3():
    return "saif" , 23,2.35,[2,4,5,8,7]

# %%
test3()
# Out:
# ('saif', 23, 2.35, [2, 4, 5, 8, 7])

# %%
a,b,c,d = test3()

# %%
a
# Out:
# 'saif'

# %%
b
# Out:
# 23

# %%
c
# Out:
# 2.35

# %%
d
# Out:
# [2, 4, 5, 8, 7]

# %%
def test4():
    a = 5+6/7
    return a

# %%
test4()
# Out:
# 5.857142857142857

# %%
def test5(a,b,c):
    d = a+b / c
    return d

# %%
test5(10,60,10)
# Out:
# 16.0

# %%
test5(100,200,50)
# Out:
# 104.0

# %%
def test6(a,b):
    return a+b

# %%
test6(5,9)
# Out:
# 14

# %%
test6 ( "saif" , " tahe")
# Out:
# 'saif tahe'

# %%
test6 ( [1,2,48] , [1,28,])
# Out:
# [1, 2, 48, 1, 28]

# %%
l = [1,2,4,87,"saif" , "tahe" , [12,4,5,6], 2.5 ]

# %%
#l1 = [ ]
#l2 = []
#for i in l:
    #if type (i) == int or type(i) == float:
    #    l1.append(i)
    #if type (i) == list:
    #    l2.append(i)'''

# %%
def test9(l):
    l1 = [ ]
    l2 = []
    for i in l:
        if type (i) == int or type(i) == float:
            l1.append(i)
        if type (i) == list:
            l2.append(i)
    return l1,l2

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
def test8(l):
    l1 = []
    for i in l:
        if type(i) == int or type (i) == float:
            l1.append(i)
    return l1

# %%
test8(l)
# Out:
# [1, 2, 4, 87, 2.5]

# %%
def test10(a):
    l1 = []
    for i in a:
        if type(i) == list:
            for j in i:
                l.append(i)
    else:
        if type(i) == int or type (i)== float :
            l.append(i)
    return a

# %%
test10(l)

# %%
l
# Out:
# [1, 2, 4, 87, 'saif', 'tahe', [12, 4, 5, 6], 2.5]
