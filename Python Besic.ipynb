# %%
#now i'm back to start my python

# %%
4+5
# Out:
# 9

# %%
8+9
# Out:
# 17

# %%
a = 45

# %%
type (a)
# Out:
# int

# %%
b = 452.2

# %%
type (b)
# Out:
# float

# %%
g = 45+54j

# %%
type (g)
# Out:
# complex

# %%
a  = 147

# %%
type (a)
# Out:
# int

# %%
1+2
# Out:
# 3

# %%
a = 10

# %%
a
# Out:
# 10

# %%
type (a)
# Out:
# int

# %%
sudh  = 1

# %%
sudh
# Out:
# 1

# %%
sudh + a
# Out:
# 11

# %%
b = 12.5

# %%
type (b)
# Out:
# float

# %%
c = 4258.25

# %%
type (c)
# Out:
# float

# %%
d = "safikul"

# %%
d
# Out:
# 'safikul'

# %%
type (d)
# Out:
# str

# %%
52.95+6325.5
# Out:
# 6378.45

# %%
e = True

# %%
f = False

# %%
type (e)
# Out:
# bool

# %%
type(f)
# Out:
# bool

# %%
e+f
# Out:
# 1

# %%
True + False
# Out:
# 1

# %%
g = 452+58j

# %%
type(g)
# Out:
# complex

# %%
g.imag
# Out:
# 58.0

# %%
g.real
# Out:
# 452.0

# %%
g
# Out:
# (452+58j)

# %%
print(g)
# Out:
# (452+58j)

# %%
h  = "safikul"

# %%
h[0]
# Out:
# 's'

# %%
h [ 5]
# Out:
# 'u'

# %%
h [ -1]
# Out:
# 'l'

# %%
h [ 0:3]
# Out:
# 'saf'

# %%
h [ 0:5:3]
# Out:
# 'si'

# %%
c = "200"

# %%
c[1]
# Out:
# '0'

# %%
c1 = 200

# %%
c1[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 c1[1]
#
# TypeError: 'int' object is not subscriptable

# %%
d = "this is my string class"

# %%
d
# Out:
# 'this is my string class'

# %%
len(d)
# Out:
# 23

# %%
d.find("is")
# Out:
# 2

# %%
d.find("iS")
# Out:
# -1

# %%
d.count("s")
# Out:
# 5

# %%
d.count("z")
# Out:
# 0

# %%
d.upper()
# Out:
# 'THIS IS MY STRING CLASS'

# %%
d
# Out:
# 'this is my string class'

# %%
d.lower()
# Out:
# 'this is my string class'

# %%
d.capitalize()
# Out:
# 'This is my string class'

# %%
d
# Out:
# 'this is my string class'

# %%
d.title()
# Out:
# 'This Is My String Class'

# %%
d +  h
# Out:
# 'this is my string classsafikul'

# %%
d*3
# Out:
# 'this is my string classthis is my string classthis is my string class'

# %%
# any positive number is a INT value and any negative number is also a INT value. it should be whole nuber like 2000

# %%
a  = 10 
b = 20
c = 30

# %%
type(b)
# Out:
# int

# %%
type(b)
# Out:
# int

# %%
type(c)
# Out:
# int

# %%
# now floteing poin number is a nothing but a decimal number. it can be positive or negative. it should be whole number like 2000.25 or -2000.25

# %%
a1 = 4288.25
b1= 1478.25
c1 = 5874.21

# %%
type(a1)
# Out:
# float

# %%
type(b1)
# Out:
# float

# %%
type(c1)
# Out:
# float

# %%
# str is a string data type. it can be a single character or a word or a sentence. it should be in single or double quotes.

# %%
a2 = "safikul"
b2 = 'khan'
c2 = "this is my string class"

# %%
type(b2)
# Out:
# str

# %%
type(a2)
# Out:
# str

# %%
type(c2)
# Out:
# str

# %%
#bool is a boolean data type. it can be either True or False. it should be in capital letter.

# %%
a3 = True
type(a3)
# Out:
# bool

# %%
a3
# Out:
# True

# %%
b3 = False
type(b3)
# Out:
# bool

# %%
a4 = 45+54j
b4 = 45-54j 
c4 = 45+54j

# %%
type(a4)
# Out:
# complex

# %%
type(b4)
# Out:
# complex

# %%
type(c4)
# Out:
# complex

# %%
#complex number is a number that has both a real part and an imaginary part. it should be in the form of a + bj or a - bj where a is the real part and b is the imaginary part. it can be positive or negative.

# %%
a4.imag
# Out:
# 54.0

# %%
a4.real
# Out:
# 45.0

# %%
# indexing and slicing in python is used to access the elements of a string. it can be done by using the index of the string. 
# the index starts from 0 and goes upto n-1 where n is the length of the string. it can be positive or negative.
# if it is positive then it starts from 0 and goes upto n-1 and if it is negative then it starts from -1 and goes upto -n where n is the length of the string.

# %%
d = "this ismy string class"
d1 = "i'm gonna learn python in 2026 end of this year"

# %%
d [ 7:10]
# Out:
# 'my '

# %%
d1 [ 0::1 ]
# Out:
# "i'm gonna learn python in 2026 end of this year"

# %%
d1 [0::]
# Out:
# "i'm gonna learn python in 2026 end of this year"

# %%
d1 [31::]
# Out:
# 'end of this year'

# %%
d1[ ::-1]
# Out:
# "raey siht fo dne 6202 ni nohtyp nrael annog m'i"

# %%
d[::-1]
# Out:
# 'ssalc gnirts ymsi siht'

# %%
d1[-1:-17:-1]
# Out:
# 'raey siht fo dne'

# %%
d1[-1:-5:-1]
# Out:
# 'raey'
