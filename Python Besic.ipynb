# %%
#now i'm back to start my python

# %%
4+5
# Out:
# 9

# %%
8+9
# Out:
# 17

# %%
a = 45

# %%
type (a)
# Out:
# int

# %%
b = 452.2

# %%
type (b)
# Out:
# float

# %%
g = 45+54j

# %%
type (g)
# Out:
# complex

# %%
a  = 147

# %%
type (a)
# Out:
# int
